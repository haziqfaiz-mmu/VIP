# %%
import numpy as np
import cv2
import pandas as pd

import pickle
from matplotlib import pyplot as pyplot
import os

from skimage.filters import roberts,sobel,scharr, prewitt
from scipy import ndimage as nd

# %% [markdown]
# 1. Read Training Images

# %%
image_dataset=pd.DataFrame(columns=["Image_Name","Pixel_Values"])

img_path = "train_images/"
for img_name in sorted(os.listdir(img_path)):
    print(img_name)

    #df=pd.DataFrame()
    #df["Image_Name"] = img_name

    input_img=cv2.imread(img_path+img_name,0)
    input_img=cv2.resize(input_img, (1050, 800))

    #Check if the image is RGB or grey and convert to grey if they are RGB
    #if input_img.ndim==3 and input_img.shape[-1]==3:
    #    img=cv2.cvtColor(input_img,cv2.COLOR_RGB2GRAY)
    #elif input_img.dim==2:
    #    img=input_img
    #else:
    #    raise Exception("Only work with RGB and grayscale images")
    
    ###################################################################################################################################
    # Add data into the dataframe
    # The first feature is the pixel values

    pixel_values=input_img.reshape(-1)
    #df["Pixel_Values"] = pixel_values
    new_row={"Image_Name":img_name,"Pixel_Values":pixel_values}
    image_dataset=pd.concat([image_dataset,pd.DataFrame([new_row])],ignore_index=True)
# Out:
# SL_001.jpg
# SL_002.jpg
# SL_003.jpg
# SL_004.jpg
# SL_005.jpg
# SL_006.jpg
# SL_007.jpg
# SL_008.jpg
# SL_009.jpg
# SL_010.jpg
# SL_011.jpg
# SL_012.jpg
# SL_013.jpg
# SL_014.jpg
# SL_015.jpg
# SL_016.jpg
# SL_017.jpg
# SL_018.jpg
# SL_019.jpg
# SL_020.jpg
# SL_021.jpg
# SL_022.jpg
# SL_023.jpg
# SL_024.jpg
# SL_025.jpg
# SL_026.jpg
# SL_027.jpg
# SL_028.jpg
# SL_029.jpg
# SL_030.jpg
# SL_031.jpg
# SL_032.jpg
# SL_033.jpg
# SL_034.jpg
# SL_035.jpg
# SL_036.jpg
# SL_037.jpg
# SL_038.jpg
# SL_039.jpg
# SL_040.jpg
# SL_041.jpg
# SL_042.jpg
# SL_043.jpg
# SL_044.jpg
# SL_045.jpg
# SL_046.jpg
# SL_047.jpg
# SL_048.jpg
# SL_049.jpg
# SL_050.jpg

# %%
for pixel in image_dataset["Pixel_Values"]:
    print(pixel.shape)
# Out:
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)

# %% [markdown]
# 2. Generate Gabor Features

# %%
gabor_df=pd.DataFrame()
gabor_df["Image_Name"]=''
for index,row in image_dataset.iterrows():
    
    img_path = "train_images/"
    img=cv2.imread(img_path+row["Image_Name"],0)
    img=cv2.resize(img, (1050, 800))

    #Check if the image is RGB or grey and convert to grey if they are RGB
    #if img.ndim==3 and img.shape[-1]==3:
    #    img=cv2.cvtColor(input_img,cv2.COLOR_RGB2GRAY)
    #elif img.dim==2:
    #    img=input_img
    #else:
    #    raise Exception("Only work with RGB and grayscale images")
    
    num=1
    kernels=[]
    filtered_img_arr=[row["Image_Name"]]

    for theta in range(2):
        theta = theta/4. *np.pi
        for sigma in (1,3):
            for lamda in np.arange(0,np.pi,np.pi/4):
                for gamma in (0.005,0.5):
                    gabor_label = 'Gabor'+str(num) #Label Gabor columns as Gabor1, Gabor2...
                    if gabor_label not in gabor_df.columns:
                        gabor_df[gabor_label]=''
                    ksize=9
                    kernel = cv2.getGaborKernel((ksize,ksize),sigma,theta,lamda,gamma,0,ktype=cv2.CV_32F)
                    kernels.append(kernel)
                    
                    #Filter image and add values to the column
                    fimg=cv2.filter2D(img,cv2.CV_8UC3,kernel)
                    filtered_img=fimg.reshape(-1)
                    #row[gabor_label]=filtered_img
                    filtered_img_arr.append(filtered_img)
                    print(gabor_label,': theta=',theta,': sigma=',sigma,': lamda=',lamda,': gamma=',gamma)
                    num+=1

    gabor_df.loc[len(gabor_df)]=filtered_img_arr

image_dataset=image_dataset.merge(gabor_df,how='left',on='Image_Name')
# Out:
# Gabor1 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor2 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor3 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor4 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor5 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor6 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor7 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor8 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor9 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor10 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor11 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor12 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor13 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor14 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor15 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor16 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor17 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor18 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor19 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor20 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor21 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor22 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor23 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor24 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor25 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor26 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor27 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor28 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor29 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor30 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor31 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor32 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor1 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor2 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor3 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor4 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor5 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor6 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor7 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor8 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor9 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor10 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor11 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor12 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor13 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor14 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor15 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor16 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor17 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor18 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor19 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor20 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor21 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor22 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor23 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor24 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor25 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor26 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor27 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor28 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor29 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor30 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor31 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor32 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor1 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor2 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor3 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor4 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor5 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor6 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor7 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor8 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor9 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor10 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor11 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor12 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor13 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor14 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor15 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor16 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor17 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor18 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor19 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor20 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor21 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor22 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor23 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor24 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor25 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor26 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor27 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor28 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor29 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor30 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor31 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor32 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor1 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor2 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor3 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor4 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor5 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor6 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor7 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor8 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor9 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor10 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor11 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor12 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor13 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor14 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor15 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor16 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor17 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor18 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor19 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor20 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor21 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor22 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor23 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor24 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor25 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor26 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor27 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor28 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor29 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor30 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor31 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor32 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor1 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor2 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor3 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor4 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor5 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor6 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor7 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor8 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor9 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor10 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor11 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor12 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor13 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor14 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor15 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor16 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor17 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor18 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor19 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor20 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor21 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor22 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor23 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor24 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor25 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor26 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor27 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor28 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor29 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor30 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor31 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor32 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor1 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor2 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor3 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor4 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor5 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor6 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor7 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor8 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor9 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor10 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor11 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor12 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor13 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor14 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor15 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor16 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor17 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor18 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor19 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor20 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor21 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor22 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor23 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor24 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor25 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor26 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor27 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor28 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor29 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor30 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor31 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor32 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor1 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor2 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor3 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor4 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor5 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor6 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor7 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor8 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor9 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor10 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor11 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor12 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor13 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor14 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor15 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor16 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor17 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor18 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor19 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor20 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor21 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor22 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor23 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor24 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor25 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor26 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor27 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor28 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor29 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor30 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor31 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor32 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor1 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor2 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor3 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor4 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor5 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor6 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor7 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor8 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor9 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor10 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor11 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor12 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor13 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor14 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor15 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor16 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor17 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor18 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor19 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor20 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor21 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor22 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor23 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor24 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor25 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor26 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor27 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor28 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor29 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor30 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor31 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor32 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor1 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor2 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor3 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor4 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor5 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor6 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor7 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor8 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor9 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor10 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor11 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor12 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor13 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor14 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor15 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor16 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor17 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor18 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor19 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor20 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor21 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor22 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor23 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor24 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor25 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor26 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor27 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor28 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor29 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor30 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor31 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor32 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor1 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor2 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor3 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor4 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor5 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor6 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor7 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor8 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor9 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor10 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor11 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor12 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor13 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor14 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor15 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor16 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor17 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor18 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor19 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor20 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor21 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor22 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor23 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor24 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor25 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor26 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor27 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor28 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor29 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor30 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor31 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor32 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor1 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor2 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor3 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor4 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor5 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor6 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor7 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor8 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor9 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor10 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor11 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor12 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor13 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor14 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor15 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor16 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor17 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor18 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor19 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor20 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor21 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor22 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor23 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor24 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor25 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor26 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor27 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor28 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor29 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor30 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor31 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor32 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor1 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor2 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor3 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor4 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor5 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor6 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor7 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor8 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor9 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor10 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor11 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor12 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor13 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor14 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor15 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor16 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor17 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor18 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor19 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor20 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor21 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor22 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor23 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor24 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor25 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor26 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor27 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor28 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor29 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor30 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor31 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor32 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor1 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor2 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor3 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor4 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor5 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor6 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor7 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor8 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor9 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor10 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor11 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor12 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor13 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor14 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor15 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor16 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor17 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor18 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor19 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor20 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor21 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor22 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor23 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor24 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor25 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor26 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor27 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor28 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor29 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor30 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor31 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor32 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor1 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor2 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor3 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor4 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor5 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor6 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor7 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor8 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor9 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor10 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor11 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor12 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor13 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor14 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor15 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor16 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor17 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor18 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor19 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor20 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor21 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor22 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor23 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor24 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor25 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor26 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor27 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor28 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor29 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor30 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor31 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor32 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor1 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor2 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor3 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor4 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor5 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor6 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor7 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor8 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor9 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor10 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor11 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor12 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor13 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor14 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor15 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor16 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor17 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor18 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor19 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor20 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor21 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor22 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor23 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor24 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor25 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor26 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor27 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor28 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor29 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor30 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor31 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor32 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor1 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor2 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor3 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor4 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor5 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor6 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor7 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor8 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor9 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor10 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor11 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor12 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor13 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor14 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor15 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor16 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor17 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor18 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor19 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor20 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor21 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor22 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor23 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor24 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor25 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor26 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor27 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor28 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor29 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor30 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor31 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor32 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor1 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor2 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor3 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor4 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor5 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor6 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor7 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor8 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor9 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor10 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor11 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor12 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor13 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor14 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor15 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor16 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor17 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor18 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor19 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor20 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor21 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor22 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor23 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor24 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor25 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor26 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor27 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor28 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor29 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor30 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor31 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor32 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor1 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor2 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor3 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor4 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor5 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor6 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor7 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor8 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor9 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor10 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor11 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor12 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor13 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor14 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor15 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor16 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor17 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor18 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor19 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor20 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor21 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor22 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor23 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor24 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor25 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor26 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor27 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor28 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor29 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor30 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor31 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor32 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor1 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor2 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor3 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor4 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor5 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor6 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor7 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor8 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor9 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor10 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor11 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor12 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor13 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor14 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor15 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor16 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor17 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor18 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor19 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor20 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor21 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor22 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor23 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor24 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor25 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor26 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor27 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor28 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor29 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor30 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor31 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor32 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor1 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor2 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor3 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor4 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor5 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor6 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor7 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor8 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor9 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor10 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor11 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor12 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor13 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor14 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor15 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# ...
# Gabor20 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor21 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor22 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor23 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor24 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor25 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor26 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor27 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor28 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor29 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor30 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor31 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor32 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor1 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor2 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor3 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor4 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor5 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor6 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor7 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor8 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor9 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor10 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor11 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor12 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor13 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor14 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor15 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor16 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor17 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor18 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor19 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor20 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor21 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor22 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor23 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor24 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor25 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor26 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor27 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor28 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor29 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor30 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor31 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor32 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor1 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor2 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor3 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor4 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor5 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor6 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor7 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor8 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor9 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor10 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor11 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor12 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor13 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor14 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor15 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor16 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor17 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor18 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor19 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor20 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor21 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor22 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor23 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor24 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor25 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor26 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor27 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor28 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor29 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor30 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor31 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor32 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor1 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor2 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor3 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor4 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor5 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor6 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor7 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor8 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor9 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor10 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor11 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor12 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor13 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor14 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor15 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor16 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor17 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor18 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor19 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor20 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor21 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor22 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor23 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor24 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor25 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor26 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor27 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor28 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor29 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor30 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor31 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor32 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor1 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor2 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor3 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor4 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor5 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor6 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor7 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor8 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor9 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor10 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor11 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor12 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor13 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor14 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor15 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor16 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor17 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor18 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor19 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor20 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor21 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor22 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor23 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor24 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor25 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor26 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor27 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor28 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor29 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor30 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor31 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor32 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor1 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor2 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor3 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor4 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor5 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor6 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor7 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor8 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor9 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor10 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor11 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor12 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor13 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor14 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor15 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor16 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor17 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor18 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor19 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor20 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor21 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor22 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor23 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor24 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor25 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor26 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor27 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor28 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor29 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor30 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor31 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor32 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor1 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor2 : theta= 0.0 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor3 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor4 : theta= 0.0 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor5 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor6 : theta= 0.0 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor7 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor8 : theta= 0.0 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor9 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor10 : theta= 0.0 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor11 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor12 : theta= 0.0 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor13 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor14 : theta= 0.0 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor15 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor16 : theta= 0.0 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor17 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.005
# Gabor18 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.0 : gamma= 0.5
# Gabor19 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor20 : theta= 0.7853981633974483 : sigma= 1 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor21 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor22 : theta= 0.7853981633974483 : sigma= 1 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor23 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor24 : theta= 0.7853981633974483 : sigma= 1 : lamda= 2.356194490192345 : gamma= 0.5
# Gabor25 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.005
# Gabor26 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.0 : gamma= 0.5
# Gabor27 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.005
# Gabor28 : theta= 0.7853981633974483 : sigma= 3 : lamda= 0.7853981633974483 : gamma= 0.5
# Gabor29 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.005
# Gabor30 : theta= 0.7853981633974483 : sigma= 3 : lamda= 1.5707963267948966 : gamma= 0.5
# Gabor31 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.005
# Gabor32 : theta= 0.7853981633974483 : sigma= 3 : lamda= 2.356194490192345 : gamma= 0.5

# %%
for e in image_dataset["Gabor2"]:
    print(e.shape)
# Out:
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)

# %% [markdown]
# 3. Generate Canny Edges

# %%
canny_df=pd.DataFrame()
canny_df["Image_Name"]=''
canny_df["Canny_Edges"]=0
for index,row in image_dataset.iterrows():
    
    img_path = "train_images/"
    img=cv2.imread(img_path+row["Image_Name"],0)
    img=cv2.resize(img, (1050, 800))

    #Check if the image is RGB or grey and convert to grey if they are RGB
    #if img.ndim==3 and img.shape[-1]==3:
    #    img=cv2.cvtColor(input_img,cv2.COLOR_RGB2GRAY)
    #elif img.dim==2:
    #    img=input_img
    #else:
    #    raise Exception("Only work with RGB and grayscale images")
    
    canny_arr=[row["Image_Name"]]

    edges=cv2.Canny(img,100,200)
    edges= edges.reshape(-1)
    canny_arr.append(edges)
                    

    canny_df.loc[len(canny_df)]=canny_arr

image_dataset=image_dataset.merge(canny_df,how='left',on='Image_Name')

# %%
for pixel in image_dataset["Canny_Edges"]:
    print(pixel.shape)
# Out:
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)

# %% [markdown]
# 4. Generate Roberts Edge

# %%
roberts_df=pd.DataFrame()
roberts_df["Image_Name"]=''
roberts_df["Roberts_Edges"]=0
for index,row in image_dataset.iterrows():
    
    img_path = "train_images/"
    img=cv2.imread(img_path+row["Image_Name"],0)
    img=cv2.resize(img, (1050, 800))

    #Check if the image is RGB or grey and convert to grey if they are RGB
    #if img.ndim==3 and img.shape[-1]==3:
    #    img=cv2.cvtColor(input_img,cv2.COLOR_RGB2GRAY)
    #elif img.dim==2:
    #    img=input_img
    #else:
    #    raise Exception("Only work with RGB and grayscale images")
    
    roberts_arr=[row["Image_Name"]]

    edges=roberts(img)
    edges= edges.reshape(-1)
    roberts_arr.append(edges)
                    

    roberts_df.loc[len(roberts_df)]=roberts_arr

image_dataset=image_dataset.merge(roberts_df,how='left',on='Image_Name')

# %%
for pixel in image_dataset["Roberts_Edges"]:
    print(pixel.shape)
# Out:
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)

# %% [markdown]
# 5. Apply Sobel Filter

# %%
sobel_df=pd.DataFrame()
sobel_df["Image_Name"]=''
sobel_df["Sobel_Edges"]=0
for index,row in image_dataset.iterrows():
    
    img_path = "train_images/"
    img=cv2.imread(img_path+row["Image_Name"],0)
    img=cv2.resize(img, (1050, 800))

    #Check if the image is RGB or grey and convert to grey if they are RGB
    #if img.ndim==3 and img.shape[-1]==3:
    #    img=cv2.cvtColor(input_img,cv2.COLOR_RGB2GRAY)
    #elif img.dim==2:
    #    img=input_img
    #else:
    #    raise Exception("Only work with RGB and grayscale images")
    
    sobel_arr=[row["Image_Name"]]

    edges=sobel(img)
    edges= edges.reshape(-1)
    sobel_arr.append(edges)
                    

    sobel_df.loc[len(sobel_df)]=sobel_arr

image_dataset=image_dataset.merge(sobel_df,how='left',on='Image_Name')

# %% [markdown]
# 6. Apply Scharr Filter

# %%
scharr_df=pd.DataFrame()
scharr_df["Image_Name"]=''
scharr_df["Scharr_Edges"]=0
for index,row in image_dataset.iterrows():
    
    img_path = "train_images/"
    img=cv2.imread(img_path+row["Image_Name"],0)
    img=cv2.resize(img, (1050, 800))

    #Check if the image is RGB or grey and convert to grey if they are RGB
    #if img.ndim==3 and img.shape[-1]==3:
    #    img=cv2.cvtColor(input_img,cv2.COLOR_RGB2GRAY)
    #elif img.dim==2:
    #    img=input_img
    #else:
    #    raise Exception("Only work with RGB and grayscale images")
    
    scharr_arr=[row["Image_Name"]]

    edges=scharr(img)
    edges= edges.reshape(-1)
    scharr_arr.append(edges)
                    

    scharr_df.loc[len(scharr_df)]=scharr_arr

image_dataset=image_dataset.merge(scharr_df,how='left',on='Image_Name')

# %% [markdown]
# 7. Apply Prewitt Filter

# %%
prewitt_df=pd.DataFrame()
prewitt_df["Image_Name"]=''
prewitt_df["Prewitt_Edges"]=0
for index,row in image_dataset.iterrows():
    
    img_path = "train_images/"
    img=cv2.imread(img_path+row["Image_Name"],0)
    img=cv2.resize(img, (1050, 800))

    #Check if the image is RGB or grey and convert to grey if they are RGB
    #if img.ndim==3 and img.shape[-1]==3:
    #    img=cv2.cvtColor(input_img,cv2.COLOR_RGB2GRAY)
    #elif img.dim==2:
    #    img=input_img
    #else:
    #    raise Exception("Only work with RGB and grayscale images")
    
    prewitt_arr=[row["Image_Name"]]

    edges=prewitt(img)
    edges= edges.reshape(-1)
    prewitt_arr.append(edges)
                    

    prewitt_df.loc[len(prewitt_df)]=prewitt_arr

image_dataset=image_dataset.merge(prewitt_df,how='left',on='Image_Name')

# %% [markdown]
# 8. Apply Gaussian Filter (sigma=3)

# %%
gaussian3_df=pd.DataFrame()
gaussian3_df["Image_Name"]=''
gaussian3_df["Gaussian3_Edges"]=0
for index,row in image_dataset.iterrows():
    
    img_path = "train_images/"
    img=cv2.imread(img_path+row["Image_Name"],0)
    img=cv2.resize(img, (1050, 800))

    #Check if the image is RGB or grey and convert to grey if they are RGB
    #if img.ndim==3 and img.shape[-1]==3:
    #    img=cv2.cvtColor(input_img,cv2.COLOR_RGB2GRAY)
    #elif img.dim==2:
    #    img=input_img
    #else:
    #    raise Exception("Only work with RGB and grayscale images")
    
    gaussian3_arr=[row["Image_Name"]]

    edges=nd.gaussian_filter(img,sigma=3)
    edges= edges.reshape(-1)
    gaussian3_arr.append(edges)
                    

    gaussian3_df.loc[len(gaussian3_df)]=gaussian3_arr

image_dataset=image_dataset.merge(gaussian3_df,how='left',on='Image_Name')

# %% [markdown]
# 9. Apply Gaussian Filter (sigma=7)

# %%
gaussian7_df=pd.DataFrame()
gaussian7_df["Image_Name"]=''
gaussian7_df["Gaussian7_Edges"]=0
for index,row in image_dataset.iterrows():
    
    img_path = "train_images/"
    img=cv2.imread(img_path+row["Image_Name"],0)
    img=cv2.resize(img, (1050, 800))

    #Check if the image is RGB or grey and convert to grey if they are RGB
    #if img.ndim==3 and img.shape[-1]==3:
    #    img=cv2.cvtColor(input_img,cv2.COLOR_RGB2GRAY)
    #elif img.dim==2:
    #    img=input_img
    #else:
    #    raise Exception("Only work with RGB and grayscale images")
    
    gaussian7_arr=[row["Image_Name"]]

    edges=nd.gaussian_filter(img,sigma=7)
    edges= edges.reshape(-1)
    gaussian7_arr.append(edges)
                    

    gaussian7_df.loc[len(gaussian7_df)]=gaussian7_arr

image_dataset=image_dataset.merge(gaussian7_df,how='left',on='Image_Name')

# %% [markdown]
# 9. Calculate 3x3 variance filter

# %%
#variance_df=pd.DataFrame()
#variance_df["Image_Name"]=''
#variance_df["Variance_Edges"]=0
#for index,row in image_dataset.iterrows():
#    
#    img_path = "train_images/"
#    img=cv2.imread(img_path+row["Image_Name"])
#    
#    variance_arr=[row["Image_Name"]]
#
#    edges=nd.generic_filter(img,np.var,size=3)
#    edges= edges.reshape(-1)
#    variance_arr.append(edges)
#                    
#
#    variance_df.loc[len(variance_df)]=variance_arr
#
#image_dataset=image_dataset.merge(variance_df,how='left',on='Image_Name')

# %% [markdown]
# 10. Load the masks

# %%
mask_path="train_masks/"
mask_arr=[]
mask_val_arr=[]
for mask in sorted(os.listdir(mask_path)):
    print(mask)
    input_mask=cv2.imread(mask_path+mask,0)
    input_mask=cv2.resize(input_mask, (1050, 800))

    #Check if the image is RGB or grey and convert to grey if they are RGB
    #if input_mask.ndim==3 and input_mask.shape[-1]==3:
    #    label=cv2.cvtColor(input_mask,cv2.COLOR_RGB2GRAY)
    #elif input_mask.dim==2:
    #    label=input_mask
    #else:
    #    raise Exception("Only work with RGB and grayscale images")
    
    mask_arr.append(mask)
    label=input_mask.reshape(-1)
    mask_val_arr.append(label)
    
image_dataset["Mask_Name"] = mask_arr
image_dataset["Label_Value"]=mask_val_arr
# Out:
# SL_GT_001.png
# SL_GT_002.png
# SL_GT_003.png
# SL_GT_004.png
# SL_GT_005.png
# SL_GT_006.png
# SL_GT_007.png
# SL_GT_008.png
# SL_GT_009.png
# SL_GT_010.png
# SL_GT_011.png
# SL_GT_012.png
# SL_GT_013.png
# SL_GT_014.png
# SL_GT_015.png
# SL_GT_016.png
# SL_GT_017.png
# SL_GT_018.png
# SL_GT_019.png
# SL_GT_020.png
# SL_GT_021.png
# SL_GT_022.png
# SL_GT_023.png
# SL_GT_024.png
# SL_GT_025.png
# SL_GT_026.png
# SL_GT_027.png
# SL_GT_028.png
# SL_GT_029.png
# SL_GT_030.png
# SL_GT_031.png
# SL_GT_032.png
# SL_GT_033.png
# SL_GT_034.png
# SL_GT_035.png
# SL_GT_036.png
# SL_GT_037.png
# SL_GT_038.png
# SL_GT_039.png
# SL_GT_040.png
# SL_GT_041.png
# SL_GT_042.png
# SL_GT_043.png
# SL_GT_044.png
# SL_GT_045.png
# SL_GT_046.png
# SL_GT_047.png
# SL_GT_048.png
# SL_GT_049.png
# SL_GT_050.png

# %%
for pixel in image_dataset["Label_Value"]:
    print(pixel.shape)
# Out:
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)
# (840000,)

# %% [markdown]
# 11. Assign Training and Test Dataset

# %%
X=image_dataset.drop(["Image_Name","Mask_Name","Label_Value"],axis=1)
X.columns
# Out:
# Index(['Pixel_Values', 'Gabor1', 'Gabor2', 'Gabor3', 'Gabor4', 'Gabor5',
#        'Gabor6', 'Gabor7', 'Gabor8', 'Gabor9', 'Gabor10', 'Gabor11', 'Gabor12',
#        'Gabor13', 'Gabor14', 'Gabor15', 'Gabor16', 'Gabor17', 'Gabor18',
#        'Gabor19', 'Gabor20', 'Gabor21', 'Gabor22', 'Gabor23', 'Gabor24',
#        'Gabor25', 'Gabor26', 'Gabor27', 'Gabor28', 'Gabor29', 'Gabor30',
#        'Gabor31', 'Gabor32', 'Canny_Edges', 'Roberts_Edges', 'Sobel_Edges',
#        'Scharr_Edges', 'Prewitt_Edges', 'Gaussian3_Edges', 'Gaussian7_Edges'],
#       dtype='object')

# %%
y=image_dataset["Label_Value"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=20)

# %%
isinstance(X["Canny_Edges"].iloc[0],np.ndarray)
# Out:
# True

# %%
columns = X_train.columns

for _,i in X_train.iterrows():
    for c in columns:
        if not isinstance(X_train[c].iloc[0],np.ndarray) :
            print(f"Row:{i}, Column:{_}")

# %%
for e in y_train:
    if not isinstance(X_train[c].iloc[0],np.ndarray) :
        print(e)

# %%
#for pixel in image_dataset["Pixel_Values"]:
#    print(pixel.shape)

# %%
#x = image_dataset["Pixel_Values"].apply(lambda x:x.shape)

# %%
#image_dataset.columns

# %%
#sane = image_dataset.drop(["Image_Name","Mask_Name"],axis=1)
#sane.columns

# %%
#for col in sane.columns:
#     sane[col]=sane[col].apply(lambda x:x.shape)

# %%
#sane["Pixel_Values"]

# %%
#sane.to_csv("sane.csv",index=False)

# %% [markdown]
# 12. Build the Random Forest model

# %%
from sklearn.ensemble import RandomForestClassifier

model=RandomForestClassifier(n_estimators=50,random_state=42)

model.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only length-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_23462/359305105.py in ?()
#       1 from sklearn.ensemble import RandomForestClassifier
#       2
#       3 model=RandomForestClassifier(n_estimators=50,random_state=42)
#       4
# ----> 5 model.fit(X_train,y_train)
#
# ~/Documents/VIP/vip-env/lib/python3.11/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1148                 skip_parameter_validation=(
#    1149                     prefer_skip_nested_validation or global_skip_validation
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#
# ~/Documents/VIP/vip-env/lib/python3.11/site-packages/sklearn/ensemble/_forest.py in ?(self, X, y, sample_weight)
#     344         """
#     345         # Validate or convert input data
#     346         if issparse(y):
#     347             raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 348         X, y = self._validate_data(
#     349             X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     350         )
#     351         if sample_weight is not None:
#
# ~/Documents/VIP/vip-env/lib/python3.11/site-packages/sklearn/base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     618                 if "estimator" not in check_y_params:
#     619                     check_y_params = {**default_check_params, **check_y_params}
#     620                 y = check_array(y, input_name="y", **check_y_params)
#     621             else:
# --> 622                 X, y = check_X_y(X, y, **check_params)
#     623             out = X, y
#     624
#     625         if not no_val_X and check_params.get("ensure_2d", True):
#
# ~/Documents/VIP/vip-env/lib/python3.11/site-packages/sklearn/utils/validation.py in ?(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1142         raise ValueError(
#    1143             f"{estimator_name} requires y to be passed, but the target y is None"
#    1144         )
#    1145
# -> 1146     X = check_array(
#    1147         X,
#    1148         accept_sparse=accept_sparse,
#    1149         accept_large_sparse=accept_large_sparse,
#
# ~/Documents/VIP/vip-env/lib/python3.11/site-packages/sklearn/utils/validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     912                         )
#     913                     array = xp.astype(array, dtype, copy=False)
#     914                 else:
#     915                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# --> 916             except ComplexWarning as complex_warning:
#     917                 raise ValueError(
#     918                     "Complex data not supported\n{}\n".format(array)
#     919                 ) from complex_warning
#
# ~/Documents/VIP/vip-env/lib/python3.11/site-packages/sklearn/utils/_array_api.py in ?(array, dtype, order, copy, xp)
#     376         # Use NumPy API to support order
#     377         if copy is True:
#     378             array = numpy.array(array, order=order, dtype=dtype)
#     379         else:
# --> 380             array = numpy.asarray(array, order=order, dtype=dtype)
#     381
#     382         # At this point array is a NumPy ndarray. We convert it to an array
#     383         # container that is consistent with the input's namespace.
#
# ~/Documents/VIP/vip-env/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, dtype)
#    2082     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#    2083         values = self._values
# -> 2084         arr = np.asarray(values, dtype=dtype)
#    2085         if (
#    2086             astype_is_view(values.dtype, arr.dtype)
#    2087             and using_copy_on_write()
#
# ValueError: setting an array element with a sequence.

# %%
#from sklearn.svm import LinearSVC
#
#model=LinearSVC(max_iter=100)
#
#model.fit(X_train,y_train)
