# %%
import cv2
import numpy as np 
from matplotlib import pyplot as plt

# %% [markdown]
# ### Select And Display 10 Test Images

# %%
selected = ['007','010', '011','016', '023','029','035','038','042','048' ]
image_arr=[]

for number in selected:
    name = 'dataset/test/SL_'+number+'.jpg'
    image = cv2.imread(name,0)
    image_arr.append(image)

# %%
def printImageArr(image_arr,x,y,size):
    plt.figure(figsize=(x,y))
    
    for index,image in enumerate(image_arr):
        plt.subplot(1,size,index+1), plt.imshow(image_arr[index],cmap='gray')
        plt.xlabel(str(selected[index])), plt.xticks([]), plt.yticks([])
    plt.show()

# %%
printImageArr(image_arr,16,10,10)

# %% [markdown]
# ## display ground truth
# ## clean image
# ## threshold
# ## morphological
# ## iterate through thresholding value

# %% [markdown]
# ### We test it with different thresholdng value.

# %%
ret1,thre=cv2.threshold(image_arr[6],140,255,cv2.THRESH_BINARY)

plt.subplot(121), plt.imshow(thre, cmap='gray')
plt.show()
